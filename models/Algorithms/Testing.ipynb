# %%
import os, sys

sys.path.append('/Users/gabrielsucich/Desktop/option_trading/')
root = '/Users/gabrielsucich/Desktop/option_trading/'

# %%
from datetime import date
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from Models.Stocks.StockHistory import *
from Models.MetricLoggers.InterdayMetrics import *
from Models.EventLoggers.InterdayChanges import *

# %%
def remove_nonconsecutive_dates(data):
    
    dates = list(data.query("Symbol == 'AAPL'")["Date"])
    dates_to_keep = []
    
    for i, date in enumerate(dates[:-1]):
        next_date = dates[i + 1]
        if days_between(date, next_date) == 1:
            dates_to_keep.append(date)
    
    return data[data["Date"].isin(dates_to_keep)]

def get_stock_data_frame_filename(granularity, volumeRecordLength, pressureRecordLength, priceRecordLength, interdayRecordLength, loadDate = None):
    
    if loadDate == None:
        current_date = date.today().strftime("%Y%m%d")
    
    else:
        current_date = loadDate
    return "StockDataFrames/{0}_g{1}_volume{2}_pressure{3}_price{4}_interday{5}".format(current_date, granularity, volumeRecordLength, pressureRecordLength, priceRecordLength, interdayRecordLength)

def import_stock_dataframe(granularity, volumeRecordLenth, pressureRecordLength, priceRecordLength, interdayRecordLength, date):
    
    data = pd.read_csv(get_stock_data_frame_filename(granularity, volumeRecordLenth, pressureRecordLength, priceRecordLength, interdayRecordLength, loadDate = date))
    data = data.drop(columns = "Unnamed: 0")
    data = remove_nonconsecutive_dates(data)
    return data

# %%
data = import_stock_dataframe("quartile", 2, 2, 2, 3, "20201225")

# %%
def find_drops(data, drop_threshold):
    
    data = data.copy()
    data["Is Drop"] = data["Next Day Change (%)"] <= -drop_threshold
    data["Is Decrease"] = data["Next Day Change (%)"] < 0
    
    return data.loc[:, "Volume Gradient": 'Prev Day Change (%)'], data[["Is Drop","Is Decrease"]]

def find_nonconsecutive_drops(data, drop_threshold):
    
    data = data.copy()
    data["Is Drop"] = (data["Next Day Change (%)"] <= -drop_threshold)&(data["Prev Day Change (%)"] > 0)
    data["Is Decrease"] = data["Next Day Change (%)"] < 0
    
    return data.loc[:, "Volume Gradient": 'Prev Day Change (%)'], data[["Is Drop","Is Decrease"]]

# %%
_, drops = find_drops(data, .5)

# %%
sum(drops.iloc[:, 0])*.07
# Out:
# 544.25

# %%
def get_TwofoldModel_metrics_filename(symbol_set_name, granularity, volumeRecordLength, pressureRecordLength, priceRecordLength, interdayRecordLength, loadDate = None):
    
    if loadDate == None:
        current_date = date.today().strftime("%Y%m%d")
    
    else:
        current_date = loadDate
    return "TwofoldModelMetrics/{0}_s{1}_g{2}_volume{3}_pressure{4}_price{5}_interday{6}".format(current_date, symbol_set_name, granularity, volumeRecordLength, pressureRecordLength, priceRecordLength, interdayRecordLength)

def export_TwofoldModel_metrics_to_csv(df, symbol_set_name, granularity, volumeRecordLength, pressureRecordLength, priceRecordLength, interdayRecordLength, loadDate = None):
    
    filename = get_TwofoldModel_metrics_filename(symbol_set_name, granularity, volumeRecordLength, pressureRecordLength, priceRecordLength, interdayRecordLength, loadDate = loadDate)
    df.to_csv(filename)
    
def import_TwofoldModel_metrics_dataframe(symbol_set_name, granularity, volumeRecordLenth, pressureRecordLength, priceRecordLength, interdayRecordLength, date):
    
    data = pd.read_csv(get_TwofoldModel_metrics_filename(symbol_set_name, granularity, volumeRecordLenth, pressureRecordLength, priceRecordLength, interdayRecordLength, loadDate = date))
    data = data.drop(columns = "Unnamed: 0")
    return data

# %%
def compile_metrics_data(symbol_set_names, date):
    
    i = 0
    
    for name in symbol_set_names:
        for granularity in granularityRange:
            for volumeRL in volumeRLRange:
                for pressureRL in pressureRLRange:
                    for priceRL in priceRLRange:
                        for interdayRL in interdayRLRange:
                            
                            if i == 0:
                                i = 1
                                data = import_TwofoldModel_metrics_dataframe(name, granularity, volumeRL, pressureRL, priceRL, interdayRL, date)
                                data["granularity"] = granularity
                                data["Volume RL"] = volumeRL
                                data["Pressure RL"] = pressureRL
                                data["Price RL"] = priceRL
                                data["Interday RL"] = interdayRL
                                data["Stock set"] = name
                            else:
                                load_data = import_TwofoldModel_metrics_dataframe(name, granularity, volumeRL, pressureRL, priceRL, interdayRL, date)
                                load_data["granularity"] = granularity
                                load_data["Volume RL"] = volumeRL
                                load_data["Pressure RL"] = pressureRL
                                load_data["Price RL"] = priceRL
                                load_data["Interday RL"] = interdayRL
                                load_data["Stock set"] = name
                                data = data.append(load_data)
    
    return data

# %%
volumeRLRange = [2, 3]
pressureRLRange = [2, 3]
priceRLRange = [2, 3]
interdayRLRange = [3, 4]
granularityRange = ["quartile"]

# %%
full_data = compile_metrics_data(["all"], "20210105")

# %%
full_data["PR-Product"] = (full_data["Precision"] - full_data["Precision Variance"]**.5)*full_data["Recall"]

# %%
full_data.query("Precision > .8").sort_values(by = "PR-Product", ascending = False).head(10)
# Out:
#    Baseline Threshold  Model Threshold  Drop Threshold  Precision  \
# 0                 0.5             0.65             0.5   0.812370
# 4                 0.6             0.65             0.5   0.804167
# 0                 0.5             0.65             0.5   0.812743
# 8                 0.7             0.65             0.5   0.826809
# 0                 0.5             0.65             0.5   0.807304
# 4                 0.6             0.65             0.5   0.800299
# 8                 0.7             0.65             0.5   0.806544
# 8                 0.7             0.65             0.5   0.824864
# 8                 0.7             0.65             0.5   0.805064
# 0                 0.5             0.65             0.5   0.802991
#
#    Precision Variance  Accuracy  Accuracy Variance    Recall  Recall Variance  \
# 0            0.003027  0.852004           0.000085  0.090885         0.000223
# 4            0.003638  0.849882           0.000056  0.076404         0.000143
# 0            0.008323  0.845120           0.000036  0.078342         0.000200
# 8            0.003775  0.850542           0.000051  0.071055         0.000069
# 0            0.004678  0.849646           0.000073  0.073243         0.000253
# 4            0.005508  0.850212           0.000043  0.072087         0.000080
# 8            0.005436  0.848845           0.000048  0.071011         0.000145
# 8            0.004647  0.849505           0.000114  0.067757         0.000193
# 8            0.006444  0.848751           0.000054  0.070442         0.000111
# 0            0.002119  0.848751           0.000058  0.066557         0.000093
#
#   granularity  Volume RL  Pressure RL  Price RL  Interday RL Stock set  \
# 0    quartile          2            3         3            4       all
# 4    quartile          3            2         3            4       all
# 0    quartile          3            3         3            4       all
# 8    quartile          2            3         3            4       all
# 0    quartile          3            3         2            4       all
# 4    quartile          2            3         2            4       all
# 8    quartile          2            2         3            3       all
# 8    quartile          3            2         2            3       all
# 8    quartile          3            3         3            4       all
# 0    quartile          2            2         2            4       all
#
#    PR-Product
# 0    0.068832
# 4    0.056833
# 0    0.056525
# 8    0.054383
# 0    0.054120
# 4    0.052341
# 8    0.052037
# 8    0.051271
# 8    0.051056
# 0    0.050381

# %% [markdown]
# The best data for nonconsecutive drops at the quartile level is:
#
# volume: 2, pressure: 3, price: 3, interday: 4
#
# bt: .5, mt: .65

# %%
volumeRLRange = [2, 3]
pressureRLRange = [2, 3]
priceRLRange = [2, 3]
interdayRLRange = [3, 4]
granularityRange = ["quartile"]

# %%
full_data = compile_metrics_data(["all"], "20201226")

# %%
full_data["PR-Product"] = (full_data["Precision"] - full_data["Precision Variance"]**.5)*full_data["Recall"]

# %%
full_data.query("Precision > .8").sort_values(by = "PR-Product", ascending = False).head(10)
# Out:
#    Baseline Threshold  Model Threshold  Drop Threshold  Precision  \
# 4                 0.6             0.65             0.5   0.840021
# 4                 0.6             0.65             0.5   0.806461
# 0                 0.5             0.65             0.5   0.815695
# 0                 0.5             0.65             0.5   0.820750
# 8                 0.7             0.65             0.5   0.812963
# 4                 0.6             0.65             0.5   0.815040
# 0                 0.5             0.65             0.5   0.813249
# 4                 0.6             0.65             0.5   0.823357
# 8                 0.7             0.65             0.5   0.821618
# 8                 0.7             0.65             0.5   0.833772
#
#    Precision Variance  Accuracy  Accuracy Variance    Recall  Recall Variance  \
# 4            0.001714  0.765394           0.000100  0.118477         0.000114
# 4            0.003336  0.765064           0.000069  0.113933         0.000215
# 0            0.002229  0.768647           0.000139  0.107680         0.000195
# 0            0.001445  0.763979           0.000115  0.102632         0.000101
# 8            0.000901  0.764356           0.000066  0.099563         0.000049
# 4            0.001692  0.764121           0.000082  0.099960         0.000058
# 0            0.001529  0.762659           0.000122  0.099926         0.000123
# 4            0.001103  0.756294           0.000091  0.096309         0.000156
# 8            0.000852  0.767091           0.000053  0.094381         0.000120
# 8            0.002588  0.760396           0.000064  0.094218         0.000050
#
#   granularity  Volume RL  Pressure RL  Price RL  Interday RL Stock set  \
# 4    quartile          3            3         3            4       all
# 4    quartile          2            3         3            4       all
# 0    quartile          3            3         3            4       all
# 0    quartile          2            3         2            4       all
# 8    quartile          2            3         3            4       all
# 4    quartile          2            3         2            4       all
# 0    quartile          3            3         2            4       all
# 4    quartile          3            3         2            4       all
# 8    quartile          3            3         2            4       all
# 8    quartile          2            3         2            4       all
#
#    PR-Product
# 4    0.094619
# 4    0.085302
# 0    0.082751
# 0    0.080333
# 8    0.077952
# 4    0.077360
# 0    0.077357
# 4    0.076098
# 8    0.074791
# 8    0.073763

# %% [markdown]
# The best data for consecutive drops at the quartile level is:
#
# volume: 3, pressure: 3, price: 3, interday: 4
#
# bt: .6, mt: .65

# %%
volumeRLRange = [3, 4]
pressureRLRange = [3, 4]
priceRLRange = [3, 4]
interdayRLRange = [3, 4]
granularityRange = ["semi"]

# %%
full_data = compile_metrics_data(["all"], "20210105")

# %%
full_data["PR-Product"] = (full_data["Precision"] - full_data["Precision Variance"]**.5)*full_data["Recall"]

# %%
full_data.query("Precision > .5").sort_values(by = "PR-Product", ascending = False).head(10)
# Out:
#    Baseline Threshold  Model Threshold  Drop Threshold  Precision  \
# 0                 0.5             0.65             0.5   0.809273
# 4                 0.6             0.65             0.5   0.838063
# 0                 0.5             0.65             0.5   0.797593
# 8                 0.7             0.65             0.5   0.804466
# 0                 0.5             0.65             0.5   0.809663
# 4                 0.6             0.65             0.5   0.811481
# 4                 0.6             0.65             0.5   0.812547
# 4                 0.6             0.65             0.5   0.789741
# 4                 0.6             0.65             0.5   0.793680
# 0                 0.5             0.65             0.5   0.800077
#
#    Precision Variance  Accuracy  Accuracy Variance    Recall  Recall Variance  \
# 0            0.002039  0.855986           0.000054  0.085906         0.000162
# 4            0.003836  0.855266           0.000047  0.084227         0.000216
# 0            0.004916  0.859226           0.000024  0.085843         0.000207
# 8            0.001962  0.857561           0.000033  0.080176         0.000105
# 0            0.002175  0.858956           0.000019  0.079801         0.000029
# 4            0.002611  0.857696           0.000082  0.076726         0.000122
# 4            0.003677  0.853915           0.000058  0.077361         0.000149
# 4            0.005933  0.859766           0.000037  0.081017         0.000530
# 4            0.001484  0.855086           0.000074  0.076325         0.000201
# 0            0.005064  0.857606           0.000030  0.078305         0.000063
#
#   granularity  Volume RL  Pressure RL  Price RL  Interday RL Stock set  \
# 0        semi          3            3         4            4       all
# 4        semi          4            4         4            3       all
# 0        semi          4            4         4            4       all
# 8        semi          3            4         4            4       all
# 0        semi          3            4         4            4       all
# 4        semi          4            3         4            4       all
# 4        semi          3            3         4            4       all
# 4        semi          4            3         3            4       all
# 4        semi          3            3         3            3       all
# 0        semi          4            4         4            3       all
#
#    PR-Product
# 0    0.065642
# 4    0.065371
# 0    0.062449
# 8    0.060948
# 0    0.060890
# 4    0.058341
# 4    0.058169
# 4    0.057742
# 4    0.057638
# 0    0.057077

# %% [markdown]
# The best data for nonconsecutive drops at the semi level is:
#
# volume: 3, pressure: 3, price: 4, interday: 4
#
# bt: .5, mt: .65

# %%
full_data = compile_metrics_data(["all"], "20201226")

# %%
full_data["PR-Product"] = (full_data["Precision"] - full_data["Precision Variance"]**.5)*full_data["Recall"]

# %%
full_data.query("Precision > .8").sort_values(by = "PR-Product", ascending = False).head(10)
# Out:
#    Baseline Threshold  Model Threshold  Drop Threshold  Precision  \
# 4                 0.6             0.65             0.5   0.837597
# 4                 0.6             0.65             0.5   0.827727
# 0                 0.5             0.65             0.5   0.806804
# 4                 0.6             0.65             0.5   0.816611
# 0                 0.5             0.65             0.5   0.815660
# 0                 0.5             0.65             0.5   0.814288
# 8                 0.7             0.65             0.5   0.828489
# 8                 0.7             0.65             0.5   0.824396
# 4                 0.6             0.65             0.5   0.805202
# 4                 0.6             0.65             0.5   0.803307
#
#    Precision Variance  Accuracy  Accuracy Variance    Recall  Recall Variance  \
# 4            0.000983  0.769487           0.000079  0.117502         0.000149
# 4            0.001160  0.769037           0.000068  0.113511         0.000029
# 0            0.001426  0.763951           0.000088  0.111470         0.000139
# 4            0.001986  0.767957           0.000025  0.107269         0.000051
# 0            0.002670  0.767327           0.000020  0.108183         0.000087
# 0            0.003327  0.768992           0.000018  0.108749         0.000137
# 8            0.000583  0.764896           0.000072  0.098739         0.000107
# 8            0.000908  0.765527           0.000075  0.098911         0.000077
# 4            0.001111  0.763051           0.000136  0.100139         0.000146
# 4            0.002340  0.766247           0.000064  0.101778         0.000166
#
#   granularity  Volume RL  Pressure RL  Price RL  Interday RL Stock set  \
# 4        semi          4            4         4            4       all
# 4        semi          4            3         4            4       all
# 0        semi          4            3         4            4       all
# 4        semi          4            3         3            4       all
# 0        semi          3            4         4            4       all
# 0        semi          3            3         3            4       all
# 8        semi          3            3         4            4       all
# 8        semi          4            4         4            4       all
# 4        semi          3            4         3            4       all
# 4        semi          4            4         3            4       all
#
#    PR-Product
# 4    0.094737
# 4    0.090091
# 0    0.085725
# 4    0.082817
# 0    0.082651
# 0    0.082280
# 8    0.079419
# 8    0.078561
# 4    0.077295
# 4    0.076835
