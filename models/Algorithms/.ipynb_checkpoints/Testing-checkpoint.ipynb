# %%
import os, sys

sys.path.append('/Users/gabrielsucich/Desktop/option_trading/')
root = '/Users/gabrielsucich/Desktop/option_trading/'

# %%
from datetime import date
import pandas as pd
import numpy as np

# %%
from Models.Stocks.StockHistory import *
from Models.MetricLoggers.InterdayMetrics import *
from Models.EventLoggers.InterdayChanges import *
# Out:
# Logged In

# %%
data = pd.read_csv("StockDataFrames/20201225_ghalfHour_volume1_pressure1_price1_interday3")
data = data.drop(columns = "Unnamed: 0")

# %%
def get_TwofoldModel_metrics_filename(symbol_set_name, granularity, volumeRecordLength, pressureRecordLength, priceRecordLength, interdayRecordLength, loadDate = None):
    
    if loadDate == None:
        current_date = date.today().strftime("%Y%m%d")
    
    else:
        current_date = loadDate
    return "TwofoldModelMetrics/{0}_s{1}_g{2}_volume{3}_pressure{4}_price{5}_interday{6}".format(current_date, symbol_set_name, granularity, volumeRecordLength, pressureRecordLength, priceRecordLength, interdayRecordLength)

def export_TwofoldModel_metrics_to_csv(df, symbol_set_name, granularity, volumeRecordLength, pressureRecordLength, priceRecordLength, interdayRecordLength, loadDate = None):
    
    filename = get_TwofoldModel_metrics_filename(symbol_set_name, granularity, volumeRecordLength, pressureRecordLength, priceRecordLength, interdayRecordLength, loadDate = loadDate)
    df.to_csv(filename)
    
def import_TwofoldModel_metrics_dataframe(symbol_set_name, granularity, volumeRecordLenth, pressureRecordLength, priceRecordLength, interdayRecordLength, date):
    
    data = pd.read_csv(get_TwofoldModel_metrics_filename(symbol_set_name, granularity, volumeRecordLenth, pressureRecordLength, priceRecordLength, interdayRecordLength, loadDate = date))
    data = data.drop(columns = "Unnamed: 0")
    return data

# %%
def compile_metrics_data(symbol_set_names, date):
    
    i = 0
    
    for name in symbol_set_names:
        for granularity in granularityRange:
            for volumeRL in volumeRLRange:
                for pressureRL in pressureRLRange:
                    for priceRL in priceRLRange:
                        for interdayRL in interdayRLRange:
                            
                            if i == 0:
                                i = 1
                                data = import_TwofoldModel_metrics_dataframe(name, granularity, volumeRL, pressureRL, priceRL, interdayRL, date)
                                data["granularity"] = granularity
                                data["Volume RL"] = volumeRL
                                data["Pressure RL"] = pressureRL
                                data["Price RL"] = priceRL
                                data["Interday RL"] = interdayRL
                                data["Stock set"] = name
                            else:
                                load_data = import_TwofoldModel_metrics_dataframe(name, granularity, volumeRL, pressureRL, priceRL, interdayRL, date)
                                load_data["granularity"] = granularity
                                load_data["Volume RL"] = volumeRL
                                load_data["Pressure RL"] = pressureRL
                                load_data["Price RL"] = priceRL
                                load_data["Interday RL"] = interdayRL
                                load_data["Stock set"] = name
                                data = data.append(load_data)
    
    return data

# %%
volumeRLRange = [1, 2]
pressureRLRange = [1, 2]
priceRLRange = [1, 2]
interdayRLRange = [3, 4]
granularityRange = ["halfHour"]

# %%
full_data = compile_metrics_data(["all"], "20201226")

# %%
def get_certain_thresholds(data, bt, mt):
    filtered_data = data[data["Baseline Threshold"] == bt]
    
    if mt < .75:
        return filtered_data[filtered_data["Model Threshold"] == mt]
    else:
        return filtered_data[filtered_data["Model Threshold"] >.7]

# %%
data55 = get_certain_thresholds(full_data, .5, .5).sort_values(by = ["Precision", "Recall"], ascending = [False, False])
data56 = get_certain_thresholds(full_data, .5, .6).sort_values(by = ["Precision", "Recall"], ascending = [False, False])
data57 = get_certain_thresholds(full_data, .5, .7).sort_values(by = ["Precision", "Recall"], ascending = [False, False])
data58 = get_certain_thresholds(full_data, .5, .8).sort_values(by = ["Precision", "Recall"], ascending = [False, False])
data65 = get_certain_thresholds(full_data, .6, .5).sort_values(by = ["Precision", "Recall"], ascending = [False, False])
data66 = get_certain_thresholds(full_data, .6, .6).sort_values(by = ["Precision", "Recall"], ascending = [False, False])
data67 = get_certain_thresholds(full_data, .6, .7).sort_values(by = ["Precision", "Recall"], ascending = [False, False])
data68 = get_certain_thresholds(full_data, .6, .8).sort_values(by = ["Precision", "Recall"], ascending = [False, False])
data75 = get_certain_thresholds(full_data, .7, .5).sort_values(by = ["Precision", "Recall"], ascending = [False, False])
data76 = get_certain_thresholds(full_data, .7, .6).sort_values(by = ["Precision", "Recall"], ascending = [False, False])
data77 = get_certain_thresholds(full_data, .7, .7).sort_values(by = ["Precision", "Recall"], ascending = [False, False])
data78 = get_certain_thresholds(full_data, .7, .8).sort_values(by = ["Precision", "Recall"], ascending = [False, False])

# %%
all_datas = [data55, data56, data57, data58, data65, data66, data67, data68, data75, data76, data77, data78]

# %%
best_datas = pd.DataFrame(columns = data.columns)
for data in all_datas:
    
    best_datas = best_datas.append(data.iloc[:2])

# %%
best_datas.sort_values(by = "Precision", ascending = False)
# Out:
#     Baseline Threshold  Model Threshold  Drop Threshold  Precision  \
# 3                  0.5              0.8             1.0   0.925000
# 3                  0.5              0.8             1.0   0.893214
# 10                 0.7              0.7             1.0   0.879038
# 11                 0.7              0.8             1.0   0.862381
# 2                  0.5              0.7             1.0   0.858996
# 6                  0.6              0.7             1.0   0.853808
# 7                  0.6              0.8             1.0   0.852597
# 10                 0.7              0.7             1.0   0.850885
# 11                 0.7              0.8             1.0   0.849048
# 7                  0.6              0.8             1.0   0.846667
# 5                  0.6              0.6             1.0   0.834078
# 6                  0.6              0.7             1.0   0.829926
# 2                  0.5              0.7             1.0   0.826084
# 9                  0.7              0.6             1.0   0.819863
# 1                  0.5              0.6             1.0   0.797127
# 5                  0.6              0.6             1.0   0.793198
# 1                  0.5              0.6             1.0   0.784225
# 9                  0.7              0.6             1.0   0.779524
# 0                  0.5              0.5             1.0   0.750919
# 0                  0.5              0.5             1.0   0.740079
# 4                  0.6              0.5             1.0   0.733237
# 8                  0.7              0.5             1.0   0.725750
# 4                  0.6              0.5             1.0   0.718239
# 8                  0.7              0.5             1.0   0.706886
#
#     Precision Variance  Accuracy  Accuracy Variance    Recall  \
# 3             0.014514  0.851438           0.000087  0.008731
# 3             0.016200  0.860113           0.000030  0.016387
# 10            0.008938  0.862046           0.000045  0.044610
# 11            0.006032  0.858369           0.000180  0.017496
# 2             0.007824  0.864828           0.000026  0.047196
# 6             0.006126  0.858793           0.000102  0.042864
# 7             0.009047  0.859689           0.000105  0.023377
# 10            0.013623  0.858510           0.000071  0.023460
# 11            0.009296  0.857756           0.000073  0.016205
# 7             0.091600  0.855634           0.000075  0.009152
# 5             0.004418  0.867374           0.000051  0.079613
# 6             0.005666  0.859830           0.000103  0.041775
# 2             0.017179  0.856247           0.000106  0.028467
# 9             0.004057  0.869826           0.000066  0.076712
# 1             0.006981  0.867232           0.000047  0.079657
# 5             0.002366  0.864875           0.000039  0.074925
# 1             0.004871  0.867138           0.000079  0.074924
# 9             0.007434  0.860066           0.000061  0.058479
# 0             0.005496  0.865818           0.000040  0.141610
# 0             0.004031  0.864639           0.000127  0.132908
# 4             0.003044  0.864451           0.000077  0.131669
# 8             0.003889  0.867280           0.000021  0.114208
# 4             0.003535  0.869448           0.000066  0.136229
# 8             0.002394  0.858887           0.000167  0.077501
#
#     Recall Variance granularity Volume RL Pressure RL Price RL Interday RL  \
# 3          0.000018    halfHour         2           2        2           3
# 3          0.000049    halfHour         1           2        1           4
# 10         0.000020    halfHour         2           2        1           4
# 11         0.000039    halfHour         1           1        1           4
# 2          0.000067    halfHour         2           2        2           4
# 6          0.000177    halfHour         1           2        2           4
# 7          0.000037    halfHour         2           2        2           4
# 10         0.000057    halfHour         2           2        2           3
# 11         0.000038    halfHour         2           2        1           4
# 7          0.000030    halfHour         2           1        2           3
# 5          0.000087    halfHour         2           2        2           4
# 6          0.000087    halfHour         2           2        2           4
# 2          0.000049    halfHour         1           2        2           3
# 9          0.000233    halfHour         1           2        1           4
# 1          0.000170    halfHour         1           2        1           4
# 5          0.000065    halfHour         1           2        1           4
# 1          0.000162    halfHour         2           2        1           4
# 9          0.000113    halfHour         2           1        1           4
# 0          0.000368    halfHour         2           2        2           4
# 0          0.000382    halfHour         2           1        2           4
# 4          0.000494    halfHour         1           2        2           4
# 8          0.000135    halfHour         2           2        2           4
# 4          0.000137    halfHour         2           2        2           4
# 8          0.000243    halfHour         2           1        2           3
#
#    Stock set
# 3        all
# 3        all
# 10       all
# 11       all
# 2        all
# 6        all
# 7        all
# 10       all
# 11       all
# 7        all
# 5        all
# 6        all
# 2        all
# 9        all
# 1        all
# 5        all
# 1        all
# 9        all
# 0        all
# 0        all
# 4        all
# 8        all
# 4        all
# 8        all

# %%
volumeRLRange = [2, 3]
pressureRLRange = [2, 3]
priceRLRange = [2, 3]
interdayRLRange = [3, 4]
granularityRange = ["quartile"]

# %%
full_data = compile_metrics_data(["all"], "20201226")

# %%
data55 = get_certain_thresholds(full_data, .5, .5).sort_values(by = ["Precision", "Recall"], ascending = [False, False])
data56 = get_certain_thresholds(full_data, .5, .6).sort_values(by = ["Precision", "Recall"], ascending = [False, False])
data57 = get_certain_thresholds(full_data, .5, .7).sort_values(by = ["Precision", "Recall"], ascending = [False, False])
data58 = get_certain_thresholds(full_data, .5, .8).sort_values(by = ["Precision", "Recall"], ascending = [False, False])
data65 = get_certain_thresholds(full_data, .6, .5).sort_values(by = ["Precision", "Recall"], ascending = [False, False])
data66 = get_certain_thresholds(full_data, .6, .6).sort_values(by = ["Precision", "Recall"], ascending = [False, False])
data67 = get_certain_thresholds(full_data, .6, .7).sort_values(by = ["Precision", "Recall"], ascending = [False, False])
data68 = get_certain_thresholds(full_data, .6, .8).sort_values(by = ["Precision", "Recall"], ascending = [False, False])
data75 = get_certain_thresholds(full_data, .7, .5).sort_values(by = ["Precision", "Recall"], ascending = [False, False])
data76 = get_certain_thresholds(full_data, .7, .6).sort_values(by = ["Precision", "Recall"], ascending = [False, False])
data77 = get_certain_thresholds(full_data, .7, .7).sort_values(by = ["Precision", "Recall"], ascending = [False, False])
data78 = get_certain_thresholds(full_data, .7, .8).sort_values(by = ["Precision", "Recall"], ascending = [False, False])

# %%
all_datas = [data55, data56, data57, data58, data65, data66, data67, data68, data75, data76, data77, data78]

# %%
best_datas = pd.DataFrame(columns = data.columns)
for data in all_datas:
    
    best_datas = best_datas.append(data.iloc[:2])

# %%
best_datas.sort_values(by = "Precision", ascending = False)
# Out:
#     Baseline Threshold  Model Threshold  Drop Threshold  Precision  \
# 7                  0.6              0.8             1.0   0.939530
# 3                  0.5              0.8             1.0   0.901923
# 7                  0.6              0.8             1.0   0.900112
# 11                 0.7              0.8             1.0   0.898413
# 3                  0.5              0.8             1.0   0.895035
# 11                 0.7              0.8             1.0   0.884762
# 9                  0.7              0.6             1.0   0.845216
# 6                  0.6              0.7             1.0   0.837574
# 2                  0.5              0.7             1.0   0.837478
# 2                  0.5              0.7             1.0   0.831201
# 6                  0.6              0.7             1.0   0.825124
# 10                 0.7              0.7             1.0   0.821425
# 10                 0.7              0.7             1.0   0.821111
# 5                  0.6              0.6             1.0   0.806235
# 9                  0.7              0.6             1.0   0.805018
# 5                  0.6              0.6             1.0   0.796996
# 1                  0.5              0.6             1.0   0.795496
# 8                  0.7              0.5             1.0   0.770552
# 1                  0.5              0.6             1.0   0.769410
# 0                  0.5              0.5             1.0   0.745373
# 8                  0.7              0.5             1.0   0.739676
# 0                  0.5              0.5             1.0   0.738374
# 4                  0.6              0.5             1.0   0.738363
# 4                  0.6              0.5             1.0   0.737272
#
#     Precision Variance  Accuracy  Accuracy Variance    Recall  \
# 7             0.007197  0.856106           0.000089  0.023438
# 3             0.007505  0.859406           0.000115  0.023530
# 7             0.007495  0.865299           0.000103  0.021016
# 11            0.021678  0.859500           0.000101  0.018468
# 3             0.005081  0.857897           0.000023  0.030720
# 11            0.015550  0.855540           0.000092  0.014320
# 9             0.003968  0.863131           0.000141  0.090181
# 6             0.009704  0.857190           0.000022  0.033187
# 2             0.003806  0.859972           0.000095  0.036206
# 2             0.012611  0.865535           0.000027  0.049635
# 6             0.004964  0.863602           0.000043  0.045897
# 10            0.011076  0.861952           0.000030  0.052022
# 10            0.010604  0.860679           0.000102  0.022112
# 5             0.011181  0.867987           0.000030  0.084145
# 9             0.007710  0.868458           0.000104  0.078432
# 5             0.009573  0.865347           0.000051  0.090208
# 1             0.007070  0.861103           0.000113  0.091815
# 8             0.006499  0.868364           0.000043  0.125161
# 1             0.006863  0.866337           0.000071  0.100847
# 0             0.002814  0.867138           0.000097  0.152217
# 8             0.001747  0.868835           0.000041  0.124603
# 0             0.001886  0.870486           0.000062  0.166439
# 4             0.002785  0.867798           0.000083  0.150487
# 4             0.003436  0.866337           0.000045  0.139997
#
#     Recall Variance granularity Volume RL Pressure RL Price RL Interday RL  \
# 7          0.000048    quartile         3           3        2           4
# 3          0.000040    quartile         3           3        2           4
# 7          0.000064    quartile         2           2        3           3
# 11         0.000016    quartile         2           2        2           3
# 3          0.000082    quartile         2           3        3           4
# 11         0.000007    quartile         3           2        2           3
# 9          0.000165    quartile         2           3        2           4
# 6          0.000042    quartile         3           2        2           3
# 2          0.000108    quartile         3           2        2           3
# 2          0.000101    quartile         3           3        2           4
# 6          0.000190    quartile         3           2        3           3
# 10         0.000167    quartile         3           2        3           4
# 10         0.000044    quartile         2           3        2           3
# 5          0.000212    quartile         2           2        2           4
# 9          0.000224    quartile         3           3        2           4
# 5          0.000209    quartile         3           3        2           4
# 1          0.000301    quartile         3           3        2           4
# 8          0.000410    quartile         3           3        3           4
# 1          0.000250    quartile         3           2        3           4
# 0          0.000317    quartile         3           3        3           4
# 8          0.000137    quartile         2           3        2           4
# 0          0.000079    quartile         3           2        3           4
# 4          0.000260    quartile         3           3        3           4
# 4          0.000345    quartile         2           3        3           4
#
#    Stock set
# 7        all
# 3        all
# 7        all
# 11       all
# 3        all
# 11       all
# 9        all
# 6        all
# 2        all
# 2        all
# 6        all
# 10       all
# 10       all
# 5        all
# 9        all
# 5        all
# 1        all
# 8        all
# 1        all
# 0        all
# 8        all
# 0        all
# 4        all
# 4        all
